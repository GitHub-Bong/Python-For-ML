# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1
    return (x,y)

def sample(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1 + np.random.randn(x.size)*0.5
    return (x,y)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
X, y = sample(1000)
plt.scatter(X, y, s=3, c="black")
plt.show()

# %%
X.shape, y.shape
# Out:
# ((1000,), (1000,))

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)
X.shape, y.shape
# Out:
# ((1000, 1), (1000, 1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X).flatten())
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)
X_poly[:10]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04],
#        [1.00000000e+00, 1.50150150e-02, 2.25450676e-04],
#        [1.00000000e+00, 2.00200200e-02, 4.00801202e-04],
#        [1.00000000e+00, 2.50250250e-02, 6.26251878e-04],
#        [1.00000000e+00, 3.00300300e-02, 9.01802704e-04],
#        [1.00000000e+00, 3.50350350e-02, 1.22745368e-03],
#        [1.00000000e+00, 4.00400400e-02, 1.60320481e-03],
#        [1.00000000e+00, 4.50450450e-02, 2.02905608e-03]])

# %%
lr = LinearRegression(fit_intercept=False)
lr.fit(X_poly,y)
# Out:
# LinearRegression(fit_intercept=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2,include_bias=False)
X_poly = poly_features.fit_transform(X)
X_poly[:10]
# Out:
# array([[0.00000000e+00, 0.00000000e+00],
#        [5.00500501e-03, 2.50500751e-05],
#        [1.00100100e-02, 1.00200300e-04],
#        [1.50150150e-02, 2.25450676e-04],
#        [2.00200200e-02, 4.00801202e-04],
#        [2.50250250e-02, 6.26251878e-04],
#        [3.00300300e-02, 9.01802704e-04],
#        [3.50350350e-02, 1.22745368e-03],
#        [4.00400400e-02, 1.60320481e-03],
#        [4.50450450e-02, 2.02905608e-03]])

# %%
lr = LinearRegression()
lr.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
poly_features = PolynomialFeatures(degree=16)
X_poly = poly_features.fit_transform(X)
X_poly[:3]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05, 1.25375751e-07,
#         6.27506263e-10, 3.14067198e-12, 1.57190790e-14, 7.86740691e-17,
#         3.93764110e-19, 1.97079134e-21, 9.86382051e-24, 4.93684710e-26,
#         2.47089445e-28, 1.23668391e-30, 6.18960915e-33, 3.09790248e-35,
#         1.55050174e-37],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04, 1.00300601e-06,
#         1.00401002e-08, 1.00501504e-10, 1.00602106e-12, 1.00702808e-14,
#         1.00803612e-16, 1.00904517e-18, 1.01005522e-20, 1.01106629e-22,
#         1.01207837e-24, 1.01309146e-26, 1.01410556e-28, 1.01512068e-30,
#         1.01613682e-32]])

# %%
lr = LinearRegression()
lr.fit(X_poly,y)
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
poly_range = list(range(10, 50))
rmse_lr_list = []
rmse_lasso_list = []
rmse_ridge_list = []

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

for poly_value in poly_range:
    poly_features = PolynomialFeatures(degree=poly_value)
    X_poly = poly_features.fit_transform(X)
    lr = LinearRegression(fit_intercept=False)
    lr.fit(X_poly,y)
    
    rmse_lr_list.append(rmse(lr.predict(X_poly), y))

    lasso = Lasso(fit_intercept=False)
    lasso.fit(X_poly,y)
    rmse_lasso_list.append(rmse(lasso.predict(X_poly), y))
    
    ridge = Ridge(fit_intercept=False)
    ridge.fit(X_poly,y)
    rmse_ridge_list.append(rmse(ridge.predict(X_poly), y))
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2418.6489197779033, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2422.5157871963074, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.85541e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2418.460007394784, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.07146e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2412.5853129930806, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.24648e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2406.3802911460034, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.68596e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2400.7170266530793, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2396.0590021142502, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2392.5766422956776, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2390.1667222990986, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2388.6523206767483, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.8260996211, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.4754727931368, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.4153267486504, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.4727072851383, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.470260614789, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.221145423539, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2386.5404779930864, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2385.2606835490897, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2383.23393330578, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2380.3538437226275, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2376.5555302098996, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2371.8221020598944, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2366.182817897338, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2359.710772254245, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2352.499647676346, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2344.6595678573253, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2336.3156806316315, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2327.60065339759, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2318.6460234210604, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2309.567625650525, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2300.4577601683277, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2291.40555296259, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2282.4969461612827, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2273.8047329476676, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2265.400661442329, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2257.331032015659, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2249.619262822418, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2242.301353111297, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2235.3918179367147, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\peter\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2228.89077781833, tolerance: 0.5503100345846815
#   model = cd_fast.enet_coordinate_descent(

# %%
import pandas as pd
from pandas import DataFrame
data = {"poly_range":poly_range, "lr_rmse":rmse_lr_list, 
        "lasso_rmse":rmse_lasso_list,"ridge_rmse":rmse_ridge_list}
df = DataFrame(data).set_index("poly_range")
df
# Out:
#              lr_rmse  lasso_rmse  ridge_rmse
# poly_range
# 10          1.906660    2.305315    1.933391
# 11          1.896263    2.307520    1.912259
# 12          1.626922    2.308023    1.910287
# 13          1.348858    2.307480    1.880017
# 14          1.335001    2.306341    1.620843
# 15          0.922366    2.305007    1.478798
# 16          0.719944    2.303750    1.487530
# 17          0.688072    2.302700    1.291637
# 18          0.712495    2.301905    0.883576
# 19          0.736951    2.301353    0.763667
# 20          0.662486    2.301015    0.754234
# 21          0.634131    2.300872    0.619885
# 22          0.547388    2.300924    0.527925
# 23          0.624076    2.301161    0.531474
# 24          0.966353    2.301565    0.674692
# 25          1.140651    2.302134    1.230706
# 26          1.213755    2.302859    1.863739
# 27          1.258728    2.303731    1.849664
# 28          1.307735    2.304747    1.509863
# 29          1.325553    2.305907    1.510270
# 30          1.306410    2.307219    1.447721
# 31          1.272106    2.308692    1.445606
# 32          1.568873    2.310340    2.049028
# 33          1.772584    2.312178    2.557141
# 34          1.665295    2.314218    2.068750
# 35          1.676012    2.316473    1.521469
# 36          1.668991    2.318948    2.033372
# 37          1.653142    2.321641    1.860535
# 38          1.636522    2.324543    1.917202
# 39          1.625774    2.327637    1.934297
# 40          1.622202    2.330907    1.861286
# 41          1.825881    2.334318    1.740290
# 42          1.658785    2.337826    2.038701
# 43          1.698674    2.341388    1.763902
# 44          1.688682    2.344962    1.803092
# 45          1.681045    2.348507    2.297644
# 46          2.101146    2.351986    1.995704
# 47          1.679354    2.355364    1.765556
# 48          2.013736    2.358612    1.799888
# 49          1.706809    2.361700    1.853038

# %%
plt.plot(poly_range, df["ridge_rmse"], label="ridge")
plt.plot(poly_range, df["lr_rmse"], label="lr")
plt.plot(poly_range, df["lasso_rmse"], label="lasso")
plt.legend()
plt.show()

# %%
df.min()
# Out:
# lr_rmse       0.547388
# lasso_rmse    2.300872
# ridge_rmse    0.527925
# dtype: float64

# %%
df["ridge_rmse"].sort_values().head()
# Out:
# poly_range
# 22    0.527925
# 23    0.531474
# 21    0.619885
# 24    0.674692
# 20    0.754234
# Name: ridge_rmse, dtype: float64

# %%
poly_features = PolynomialFeatures(degree=22)
X_poly = poly_features.fit_transform(X)
ridge = Ridge(fit_intercept=False)
ridge.fit(X_poly,y)
# Out:
# Ridge(fit_intercept=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), ridge.predict(X_poly).flatten())
plt.show()
